# %%
import yfinance as yf
import pandas as pd

# %%
sym3="TSLA"
tesla=yf.Ticker(sym3)

df3=tesla.history(period="max",rounding=True)
df3

tesla_data=df3.head()
tesla_data
# Out:
#                            Open  High   Low  Close     Volume  Dividends  \
# Date
# 2010-06-29 00:00:00-04:00  1.27  1.67  1.17   1.59  281494500        0.0
# 2010-06-30 00:00:00-04:00  1.72  2.03  1.55   1.59  257806500        0.0
# 2010-07-01 00:00:00-04:00  1.67  1.73  1.35   1.46  123282000        0.0
# 2010-07-02 00:00:00-04:00  1.53  1.54  1.25   1.28   77097000        0.0
# 2010-07-06 00:00:00-04:00  1.33  1.33  1.06   1.07  103003500        0.0
#
#                            Stock Splits
# Date
# 2010-06-29 00:00:00-04:00           0.0
# 2010-06-30 00:00:00-04:00           0.0
# 2010-07-01 00:00:00-04:00           0.0
# 2010-07-02 00:00:00-04:00           0.0
# 2010-07-06 00:00:00-04:00           0.0

# %%
sym1="amzn"
amazon=yf.Ticker(sym1)

# %%
df1=amazon.history(period="max",rounding=True)
df1
# Out:
#                              Open    High     Low   Close      Volume  \
# Date
# 1997-05-15 00:00:00-04:00    0.12    0.12    0.10    0.10  1443120000
# 1997-05-16 00:00:00-04:00    0.10    0.10    0.09    0.09   294000000
# 1997-05-19 00:00:00-04:00    0.09    0.09    0.08    0.09   122136000
# 1997-05-20 00:00:00-04:00    0.09    0.09    0.08    0.08   109344000
# 1997-05-21 00:00:00-04:00    0.08    0.08    0.07    0.07   377064000
# ...                           ...     ...     ...     ...         ...
# 2023-09-12 00:00:00-04:00  142.32  143.00  140.61  141.23    42668500
# 2023-09-13 00:00:00-04:00  140.95  144.98  140.87  144.85    60465200
# 2023-09-14 00:00:00-04:00  145.08  145.86  142.95  144.72    64033600
# 2023-09-15 00:00:00-04:00  142.69  143.57  140.09  140.39   102861700
# 2023-09-18 00:00:00-04:00  140.48  141.73  139.22  139.98    39984835
#
#                            Dividends  Stock Splits
# Date
# 1997-05-15 00:00:00-04:00        0.0           0.0
# ...

# %%
amazon.info["country"]
# Out:
# 'United States'

# %%
df1=amazon.history(period="max",rounding=True)["Open"]
df1
# Out:
# Date
# 1997-05-15 00:00:00-04:00      0.12
# 1997-05-16 00:00:00-04:00      0.10
# 1997-05-19 00:00:00-04:00      0.09
# 1997-05-20 00:00:00-04:00      0.09
# 1997-05-21 00:00:00-04:00      0.08
#                               ...
# 2023-09-07 00:00:00-04:00    133.90
# 2023-09-08 00:00:00-04:00    136.86
# 2023-09-11 00:00:00-04:00    138.75
# 2023-09-12 00:00:00-04:00    142.32
# 2023-09-13 00:00:00-04:00    140.95
# Name: Open, Length: 6626, dtype: float64

# %%
df1.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1=amazon.history(period="max",rounding=True)

# %%
amazon.dividends.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
sym2="AMD"
amd=yf.Ticker(sym2)

# %%
df2=amd.history(period="max",rounding=True,)
df2
# Out:
#                              Open    High     Low   Close    Volume  \
# Date
# 1980-03-17 00:00:00-05:00    0.00    3.30    3.12    3.15    219600
# 1980-03-18 00:00:00-05:00    0.00    3.12    2.94    3.03    727200
# 1980-03-19 00:00:00-05:00    0.00    3.08    3.02    3.04    295200
# 1980-03-20 00:00:00-05:00    0.00    3.06    3.01    3.01    159600
# 1980-03-21 00:00:00-05:00    0.00    3.02    2.91    2.92    130800
# ...                           ...     ...     ...     ...       ...
# 2023-09-08 00:00:00-04:00  107.02  109.74  105.75  106.09  46232000
# 2023-09-11 00:00:00-04:00  107.32  107.51  103.00  105.32  50611300
# 2023-09-12 00:00:00-04:00  104.20  106.74  103.18  105.31  44413600
# 2023-09-13 00:00:00-04:00  105.10  108.74  104.83  107.71  44651300
# 2023-09-14 00:00:00-04:00  108.43  109.15  106.67  107.18   9223585
#
#                            Dividends  Stock Splits
# Date
# 1980-03-17 00:00:00-05:00        0.0           0.0
# ...

# %%
amd.info
# Out:
# {'address1': '2485 Augustine Drive',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95054',
#  'country': 'United States',
#  'phone': '408 749 4000',
#  'website': 'https://www.amd.com',
#  'industry': 'Semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
# ...

# %%
df2_open=amd.history(period="max",rounding=True)["Open"]
df2_open
# Out:
# Date
# 1980-03-17 00:00:00-05:00      0.00
# 1980-03-18 00:00:00-05:00      0.00
# 1980-03-19 00:00:00-05:00      0.00
# 1980-03-20 00:00:00-05:00      0.00
# 1980-03-21 00:00:00-05:00      0.00
#                               ...
# 2023-09-08 00:00:00-04:00    107.02
# 2023-09-11 00:00:00-04:00    107.32
# 2023-09-12 00:00:00-04:00    104.20
# 2023-09-13 00:00:00-04:00    105.10
# 2023-09-14 00:00:00-04:00    108.43
# Name: Open, Length: 10967, dtype: float64

# %%
df2_open.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tesla.info
# Out:
# {'address1': '1 Tesla Road',
#  'city': 'Austin',
#  'state': 'TX',
#  'zip': '78725',
#  'country': 'United States',
#  'phone': '512 516 8177',
#  'website': 'https://www.tesla.com',
#  'industry': 'Auto Manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
df3_open=tesla.history(period="max",rounding=True)["Open"]
df3_open
# Out:
# Date
# 2010-06-29 00:00:00-04:00      1.27
# 2010-06-30 00:00:00-04:00      1.72
# 2010-07-01 00:00:00-04:00      1.67
# 2010-07-02 00:00:00-04:00      1.53
# 2010-07-06 00:00:00-04:00      1.33
#                               ...
# 2023-09-07 00:00:00-04:00    245.07
# 2023-09-08 00:00:00-04:00    251.22
# 2023-09-11 00:00:00-04:00    264.27
# 2023-09-12 00:00:00-04:00    270.76
# 2023-09-13 00:00:00-04:00    270.07
# Name: Open, Length: 3325, dtype: float64

# %%
df3_open.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
sym4="GME"
gme=yf.Ticker(sym4)

df4=gme.history(period="max",rounding=True)
gme_data=df4.head()
gme_data

# %%
gme.info
# Out:
# {'address1': '625 Westport Parkway',
#  'city': 'Grapevine',
#  'state': 'TX',
#  'zip': '76051',
#  'country': 'United States',
#  'phone': '817 424 2000',
#  'website': 'https://www.gamestop.com',
#  'industry': 'Specialty Retail',
#  'industryDisp': 'Specialty Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
df4_open=gme.history(period="max",rounding=True)["Open"]
df4_open
# Out:
# Date
# 2002-02-13 00:00:00-05:00     1.62
# 2002-02-14 00:00:00-05:00     1.71
# 2002-02-15 00:00:00-05:00     1.68
# 2002-02-19 00:00:00-05:00     1.67
# 2002-02-20 00:00:00-05:00     1.62
#                              ...
# 2023-09-08 00:00:00-04:00    18.15
# 2023-09-11 00:00:00-04:00    17.85
# 2023-09-12 00:00:00-04:00    17.53
# 2023-09-13 00:00:00-04:00    17.31
# 2023-09-14 00:00:00-04:00    17.80
# Name: Open, Length: 5434, dtype: float64

# %%
df4_open.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html"
page=requests.get(url)
soup=BeautifulSoup(page.text,"html5lib")

# %%
soup.title.text
# Out:
# 'Amazon.com, Inc. (AMZN) Stock Historical Prices & Data - Yahoo Finance'

# %%
soup.find_all("table")
# Out:
# [<table class="W(100%) M(0)" data-reactid="33" data-test="historical-prices"><thead data-reactid="34"><tr class="C($tertiaryColor) Fz(xs) Ta(end)" data-reactid="35"><th class="Ta(start) W(100px) Fw(400) Py(6px)" data-reactid="36"><span data-reactid="37">Date</span></th><th class="Fw(400) Py(6px)" data-reactid="38"><span data-reactid="39">Open</span></th><th class="Fw(400) Py(6px)" data-reactid="40"><span data-reactid="41">High</span></th><th class="Fw(400) Py(6px)" data-reactid="42"><span data-reactid="43">Low</span></th><th class="Fw(400) Py(6px)" data-reactid="44"><span data-reactid="45">Close*</span></th><th class="Fw(400) Py(6px)" data-reactid="46"><span data-reactid="47">Adj Close**</span></th><th class="Fw(400) Py(6px)" data-reactid="48"><span data-reactid="49">Volume</span></th></tr></thead><tbody data-reactid="50"><tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)" data-reactid="51"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="52"><span data-reactid="53">Jun
# ...

# %%
table=soup.find("table",class_=
                {"W(100%) M(0)"})

# %%
#table=soup.find_all("div", class_="Pb(10px) Ovx(a) W(100%)")
columns=["Date", "Open", "High", "Low", "Close", "Adj close", "Volume"]
amazon_data = pd.DataFrame(columns=columns)

Date =""
Open =""
High =""
Low = ""
Close =""
Adj_close =""
Volume =""
i=1
for tr in table.find_all("tr"):
    i=0
    for td in tr.find_all("td"):
        i=i+1
        if (i==1):
            Date=td.text.replace("\n","")
        if (i==2):
            Open=td.text.replace("\n","")
        if(i==3):
            High=td.text.replace("\n","")
        if(i==4):
            Low=td.text.replace("\n","")
        if(i==5):
            Close=td.text.replace("\n","")
        if(i==6):
            Adj_close=td.text.replace("\n","")
        if(i==7):
            Volume=td.text.replace("\n","")

    if (Date!=""):
            amazon_data=amazon_data.append(
                pd.Series([Date,
                           Open,
                           High,
                           Low,
                           Close,
                           Adj_close,
                           Volume]
                            ,index=columns)
                         ,ignore_index=True)

amazon_data
# Out:
# C:\Users\AL-AZHARY\AppData\Local\Temp\ipykernel_7824\334052219.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data=amazon_data.append(
# C:\Users\AL-AZHARY\AppData\Local\Temp\ipykernel_7824\334052219.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data=amazon_data.append(
# C:\Users\AL-AZHARY\AppData\Local\Temp\ipykernel_7824\334052219.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data=amazon_data.append(
# C:\Users\AL-AZHARY\AppData\Local\Temp\ipykernel_7824\334052219.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data=amazon_data.append(
# ...

# %%
read_html=pd.read_html(str(url))
read_html
# Out:
# [                                                 Date  \
#  0                                        Jan 01, 2021
#  1                                        Dec 01, 2020
#  2                                        Nov 01, 2020
#  3                                        Oct 01, 2020
#  4                                        Sep 01, 2020
#  ..                                                ...
#  57                                       Apr 01, 2016
#  58                                       Mar 01, 2016
#  59                                       Feb 01, 2016
#  60                                       Jan 01, 2016
#  61  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
#  0                                             3270.00
#  1                                             3188.50
#  2                                             3061.74
#  3                                             3208.00
# ...
